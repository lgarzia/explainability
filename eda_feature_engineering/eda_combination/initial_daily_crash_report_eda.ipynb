# %%
import dataprep.connector as dbc
import urllib
mshp_db_path = r"C:\Users\lgarzia\Documents\GitHub\explainability\local_data\data\mshp.sqlite" 
mshp_db_path = urllib.parse.quote(mshp_db_path)
mshp_db_conn = "sqlite://"+mshp_db_path
df = dbc.read_sql(mshp_db_conn, "SELECT * FROM daily_crash_report")

# %%
from ydata_profiling import ProfileReport
# Out:
# Pandas backend loaded 1.5.3
# Numpy backend loaded 1.23.5
# Pyspark backend NOT loaded
# Python backend loaded

# %%
profile = ProfileReport(df, title="initial_daily_crash_report_eda")

# %%
profile.to_file("initial_daily_crash_report_eda.html")
# Out:
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_g = df.groupby(['acc_rpt_num', 'Name']).filter(lambda x: x['index'].count() > 1)
df_g[df_g['Name'] != 'JUVENILE,']
# Out:
#        index                                           raw_href acc_rpt_num  \
# 4055       4  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220329749
# 4056       5  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220329749
# 4513      15  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220352240
# 4514      16  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220352240
# 5295       2  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220393068
# 5296       3  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220393068
# 5582       8  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220405438
# 5583       9  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220405438
# 10014     13  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220597534
# 10015     14  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220597534
# 11086     16  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220655438
# 11087     17  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220655438
# 11514     31  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220672716
# 11515     32  https://www.mshp.dps.missouri.gov/HP68/Acciden...   220672716
#
#                                    acc_uuid Report                  Name  Age  \
# 4055   fc87b738-d001-4e46-b6d9-230270a107dd   View  SMALLWOOD, MICHAEL A   55
# 4056   251f9c11-c444-4911-a056-594e5af5e64b   View  SMALLWOOD, MICHAEL A   56
# 4513   1c87851b-3045-42bb-82a3-b45b241a9899   View  GILIO, CHRISTOPHER A   31
# 4514   bcf61052-99b1-45b1-8416-c0b77df5a108   View  GILIO, CHRISTOPHER A   56
# 5295   54113866-baaa-4adc-8bd5-bfaf21d78caa   View     WALTERS, MARTHA P   45
# 5296   2319713d-abe7-4b82-8ff5-a603662ebd09   View     WALTERS, MARTHA P   47
# 5582   fc85e681-9cca-453e-b420-deb71acacd1e   View     SMITH, ABBYGALE R   18
# 5583   a0629794-c376-4f81-b29f-276f0d67b168   View     SMITH, ABBYGALE R   21
# 10014  9735d7ee-3319-42c2-821e-d1fe0e37841e   View          LONG, JOHN C   50
# 10015  d9d67244-354f-4c99-8c6f-1595fbaedddd   View          LONG, JOHN C   59
# 11086  2a7d2bd0-2d63-43f4-b5e4-8cbf6ad4607a   View     PALMGREN, ROGER H   83
# 11087  2617dc23-6294-4f43-bc93-6dc661c8b2be   View     PALMGREN, ROGER H  UNK
# 11514  1c17a2f9-6ab4-41fe-803e-e8120e9440cc   View      DEMOTTE, TERRY L   40
# 11515  cc0993e5-e3b6-4b01-8fa1-9df0767175ed   View      DEMOTTE, TERRY L  UNK
#
#       Person City/State Personal Injury Safety Device        Date     Time  \
# 4055     KANSAS CITY MO       NO INJURY           YES  06/23/2022   9:45PM
# 4056     KANSAS CITY MO           MINOR           YES  06/23/2022   9:45PM
# 4513          LENEXA KS        MODERATE            NO  07/03/2022   5:20PM
# 4514         LENEXA, KS         SERIOUS            NO  07/03/2022   5:20PM
# 5295         HOLDEN, MO        MODERATE            NO  07/23/2022   9:00PM
# 5296         HOLDEN, MO       NO INJURY            NO  07/23/2022   9:00PM
# 5582       SULLIVAN, MO           MINOR           YES  07/30/2022   5:00PM
# 5583       SULLIVAN, MO       NO INJURY           YES  07/30/2022   5:00PM
# 10014        DREXEL, MO         SERIOUS            NO  11/12/2022   8:33AM
# 10015        DREXEL, MO       NO INJURY            NO  11/12/2022   8:33AM
# 11086        EXCELLO MO           FATAL           YES  12/14/2022   3:24PM
# 11087        EXCELLO MO       NO INJURY           YES  12/14/2022   3:24PM
# 11514    KINGSVILLE, MO        MODERATE            NO  12/24/2022  12:35PM
# 11515    KINGSVILLE, MO        MODERATE       UNKNOWN  12/24/2022  12:35PM
#
#       Crash County                                     Crash Location Troop
# 4055       JACKSON                        RAYTOWN ROAD AT E 71ST TERR     A
# 4056       JACKSON                        RAYTOWN ROAD AT E 71ST TERR     A
# 4513        MORGAN               RED ARROW RD 52 FEET WEST OF COOK RD     F
# 4514        MORGAN               RED ARROW RD 52 FEET WEST OF COOK RD     F
# 5295          CASS  EASTBOUND MO-58 APPROXIMATELY 1 MILE EAST OF R...     A
# 5296          CASS  EASTBOUND MO-58 APPROXIMATELY 1 MILE EAST OF R...     A
# 5582      FRANKLIN       EASTBOUND E SPRINGFIELD ST AT NORTHBOUND 185     C
# 5583      FRANKLIN       EASTBOUND E SPRINGFIELD ST AT NORTHBOUND 185     C
# 10014        BATES                          RT AA EAST OF NW CR 10001     A
# 10015        BATES                          RT AA EAST OF NW CR 10001     A
# 11086        MACON                               US 63 AT EXCELLO JCT     B
# 11087        MACON                               US 63 AT EXCELLO JCT     B
# 11514      JACKSON                           US 50 AT S AL GOSSETT RD     A
# 11515      JACKSON                           US 50 AT S AL GOSSETT RD     A

# %%
df[df['Name']=='GARZA, PATRICIA R']
# Out:
#       index                                           raw_href acc_rpt_num  \
# 6505     19  https://www.mshp.dps.missouri.gov/HP68/Acciden...   200450441
#
#                                   acc_uuid Report               Name Age  \
# 6505  829e60b9-8d83-4f82-bbf3-c838949a7473   View  GARZA, PATRICIA R  50
#
#      Person City/State Personal Injury Safety Device        Date    Time  \
# 6505  POPLAR BLUFF, MO        MODERATE           YES  08/23/2022  4:07PM
#
#      Crash County            Crash Location Troop
# 6505      MADISON  US 67 - AT CHEROKEE PASS     E
