# %%
import dataprep.connector as dbc
import urllib
table_name = "injury_information"
mshp_db_path = r"C:\Users\lgarzia\Documents\GitHub\explainability\local_data\data\mshp.sqlite" 
mshp_db_path = urllib.parse.quote(mshp_db_path)
mshp_db_conn = "sqlite://"+mshp_db_path

# %%
sql = '''
WITH n AS
(
	SELECT acc_rpt_num, CASE WHEN max(veh_num) > 1 THEN 'MULTI' ELSE 'SINGLE' END AS num_veh
	FROM pre_feature_eng_base
	group by acc_rpt_num
)
SELECT e.*, num_veh 
FROM pre_feature_eng_base e JOIN n on e.acc_rpt_num = n.acc_rpt_num
'''

# %%
df = dbc.read_sql(mshp_db_conn, sql)

# %%
# Target Variable
df['injury_type'].value_counts(normalize=True)
# Out:
# MINOR        0.319291
# NO INJURY    0.283677
# MODERATE     0.201979
# SERIOUS      0.145095
# FATAL        0.049959
# Name: injury_type, dtype: float64

# %%
df['injury_type'] = df['injury_type'].map({'MINOR': 0, 'NO INJURY': 0, 'MODERATE':0, 'SERIOUS':1, 'FATAL':1})

# %%
df.drop(['acc_rpt_num', 'acc_uuid', 'name', 'veh_num'], axis=1, inplace=True)

# %%
df
# Out:
#        injury_type age       city_state safety_device        date     time  \
# 0                0  38  HOWARDVILLE, MO            NO  03/06/2022   9:24PM
# 1                0  48     PECULIAR, MO           YES  03/06/2022   9:15PM
# 2                0  38       LATOUR, MO           YES  03/06/2022   9:15PM
# 3                0  59     NORBORNE, MO           YES  03/06/2022   8:18PM
# 4                1  19       CONWAY, MO            NO  03/06/2022   8:15PM
# ...            ...  ..              ...           ...         ...      ...
# 12125            0  74  SPRINGFIELD, MO           YES  03/05/2023  12:45PM
# 12126            0  86         NIXA, MO           YES  03/05/2023  12:45PM
# 12127            0  27   FLORISSANT, MO            NO  03/05/2023   3:57AM
# 12128            1  19     RICHMOND, MO            NO  03/05/2023   1:40AM
# 12129            0  23    ST. LOUIS, MO            NO  03/05/2023  12:10AM
#
#       troop  gender involvement vehicle_direction num_veh
# 0         E    MALE      DRIVER        SOUTHBOUND  SINGLE
# 1         A    MALE      DRIVER        NORTHBOUND   MULTI
# 2         A    MALE      DRIVER        NORTHBOUND   MULTI
# 3         A    MALE      DRIVER         EASTBOUND  SINGLE
# 4         I    MALE      DRIVER        SOUTHBOUND  SINGLE
# ...     ...     ...         ...               ...     ...
# 12125     D    MALE      DRIVER        NORTHBOUND   MULTI
# 12126     D  FEMALE      DRIVER         EASTBOUND   MULTI
# 12127     C    MALE      DRIVER         EASTBOUND  SINGLE
# 12128     A    MALE      DRIVER         WESTBOUND  SINGLE
# 12129     C  FEMALE      DRIVER         WESTBOUND  SINGLE
#
# [12130 rows x 11 columns]

# %%
# instate version out of state - low information mostly MO and long tail clean up
df['city_state'].str.split(',').str[-1].value_counts()
# Out:
#  MO               9098
#  IL                264
#  MISSOURI          235
# MO                 203
#  KS                201
#                   ...
# LONE JACK            1
# SHELL KNOB. MO       1
# GILLESPIE IL         1
# BERKELEY MO          1
# CLINTON/MO           1
# Name: city_state, Length: 544, dtype: int64

# %%
df.drop(['city_state'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    injury_type age safety_device        date    time troop gender involvement  \
# 0            0  38            NO  03/06/2022  9:24PM     E   MALE      DRIVER
# 1            0  48           YES  03/06/2022  9:15PM     A   MALE      DRIVER
# 2            0  38           YES  03/06/2022  9:15PM     A   MALE      DRIVER
# 3            0  59           YES  03/06/2022  8:18PM     A   MALE      DRIVER
# 4            1  19            NO  03/06/2022  8:15PM     I   MALE      DRIVER
#
#   vehicle_direction num_veh
# 0        SOUTHBOUND  SINGLE
# 1        NORTHBOUND   MULTI
# 2        NORTHBOUND   MULTI
# 3         EASTBOUND  SINGLE
# 4        SOUTHBOUND  SINGLE

# %%
import pandas as pd
df['month_name'] = pd.to_datetime(df.date).dt.month_name()

# %%
# https://ianlondon.github.io/blog/encoding-cyclical-features-24hour-time/
df['seconds'] = pd.to_datetime(df.time).dt.hour*60*60 +  pd.to_datetime(df.time).dt.minute*60
seconds_in_day = 24*60*60
import numpy as np
df['sin_time'] = np.sin(2*np.pi*df.seconds/seconds_in_day)
df['cos_time'] = np.cos(2*np.pi*df.seconds/seconds_in_day)

# %%
df.drop(['date', 'time', 'seconds'], axis=1, inplace=True)

# %%
df
# Out:
#        injury_type age safety_device troop  gender involvement  \
# 0                0  38            NO     E    MALE      DRIVER
# 1                0  48           YES     A    MALE      DRIVER
# 2                0  38           YES     A    MALE      DRIVER
# 3                0  59           YES     A    MALE      DRIVER
# 4                1  19            NO     I    MALE      DRIVER
# ...            ...  ..           ...   ...     ...         ...
# 12125            0  74           YES     D    MALE      DRIVER
# 12126            0  86           YES     D  FEMALE      DRIVER
# 12127            0  27            NO     C    MALE      DRIVER
# 12128            1  19            NO     A    MALE      DRIVER
# 12129            0  23            NO     C  FEMALE      DRIVER
#
#       vehicle_direction num_veh  seconds  sin_time  cos_time month_name
# 0            SOUTHBOUND  SINGLE    77040 -0.629320  0.777146      March
# 1            NORTHBOUND   MULTI    76500 -0.659346  0.751840      March
# 2            NORTHBOUND   MULTI    76500 -0.659346  0.751840      March
# 3             EASTBOUND  SINGLE    73080 -0.824126  0.566406      March
# 4            SOUTHBOUND  SINGLE    72900 -0.831470  0.555570      March
# ...                 ...     ...      ...       ...       ...        ...
# 12125        NORTHBOUND   MULTI    45900 -0.195090 -0.980785      March
# 12126         EASTBOUND   MULTI    45900 -0.195090 -0.980785      March
# 12127         EASTBOUND  SINGLE    14220  0.859406  0.511293      March
# 12128         WESTBOUND  SINGLE     6000  0.422618  0.906308      March
# 12129         WESTBOUND  SINGLE      600  0.043619  0.999048      March
#
# [12130 rows x 12 columns]

# %%
df.gender.value_counts()
# Out:
# MALE       7489
# FEMALE     4550
# UNKNOWN      61
# Name: gender, dtype: int64

# %%
df.involvement.value_counts()
# Out:
# DRIVER        10171
# OCCUPANT       1803
# PEDESTRIAN      140
# BICYCLIST        14
# OTHER             2
# Name: involvement, dtype: int64

# %%
df['is_driver'] = np.where(df.involvement == 'DRIVER', 1, 0)

# %%
df.drop(['involvement'], axis=1, inplace=True)

# %%
df.head(n=6)
# Out:
#    injury_type age safety_device troop  gender vehicle_direction num_veh  \
# 0            0  38            NO     E    MALE        SOUTHBOUND  SINGLE
# 1            0  48           YES     A    MALE        NORTHBOUND   MULTI
# 2            0  38           YES     A    MALE        NORTHBOUND   MULTI
# 3            0  59           YES     A    MALE         EASTBOUND  SINGLE
# 4            1  19            NO     I    MALE        SOUTHBOUND  SINGLE
# 5            1  37           YES     H  FEMALE         EASTBOUND  SINGLE
#
#    seconds  sin_time  cos_time month_name  is_driver
# 0    77040 -0.629320  0.777146      March          1
# 1    76500 -0.659346  0.751840      March          1
# 2    76500 -0.659346  0.751840      March          1
# 3    73080 -0.824126  0.566406      March          1
# 4    72900 -0.831470  0.555570      March          1
# 5    71220 -0.892979  0.450098      March          1

# %%
df['vehicle_direction'] = df.vehicle_direction.str[:1].apply(lambda x: x if x in set(['E', 'W', 'N', 'S']) else 'U')

# %%
df.head(n=5)
# Out:
#    injury_type age safety_device troop gender vehicle_direction num_veh  \
# 0            0  38            NO     E   MALE                 S  SINGLE
# 1            0  48           YES     A   MALE                 N   MULTI
# 2            0  38           YES     A   MALE                 N   MULTI
# 3            0  59           YES     A   MALE                 E  SINGLE
# 4            1  19            NO     I   MALE                 S  SINGLE
#
#    seconds  sin_time  cos_time month_name  is_driver
# 0    77040 -0.629320  0.777146      March          1
# 1    76500 -0.659346  0.751840      March          1
# 2    76500 -0.659346  0.751840      March          1
# 3    73080 -0.824126  0.566406      March          1
# 4    72900 -0.831470  0.555570      March          1

# %%
df.troop.value_counts()
# Out:
# C    3379
# D    2222
# A    1869
# E    1197
# F    1037
# I     718
# G     617
# B     554
# H     537
# Name: troop, dtype: int64

# %%
df.gender.value_counts()
# Out:
# MALE       7489
# FEMALE     4550
# UNKNOWN      61
# Name: gender, dtype: int64

# %%
df
# Out:
#        injury_type age safety_device troop  gender vehicle_direction num_veh  \
# 0                0  38            NO     E    MALE                 S  SINGLE
# 1                0  48           YES     A    MALE                 N   MULTI
# 2                0  38           YES     A    MALE                 N   MULTI
# 3                0  59           YES     A    MALE                 E  SINGLE
# 4                1  19            NO     I    MALE                 S  SINGLE
# ...            ...  ..           ...   ...     ...               ...     ...
# 12125            0  74           YES     D    MALE                 N   MULTI
# 12126            0  86           YES     D  FEMALE                 E   MULTI
# 12127            0  27            NO     C    MALE                 E  SINGLE
# 12128            1  19            NO     A    MALE                 W  SINGLE
# 12129            0  23            NO     C  FEMALE                 W  SINGLE
#
#        sin_time  cos_time month_name  is_driver
# 0     -0.629320  0.777146      March          1
# 1     -0.659346  0.751840      March          1
# 2     -0.659346  0.751840      March          1
# 3     -0.824126  0.566406      March          1
# 4     -0.831470  0.555570      March          1
# ...         ...       ...        ...        ...
# 12125 -0.195090 -0.980785      March          1
# 12126 -0.195090 -0.980785      March          1
# 12127  0.859406  0.511293      March          1
# 12128  0.422618  0.906308      March          1
# 12129  0.043619  0.999048      March          1
#
# [12130 rows x 11 columns]

# %%
import sqlite3 
mshp_db_path = r"C:\Users\lgarzia\Documents\GitHub\explainability\local_data\data\mshp.sqlite" 
conn = sqlite3.connect(mshp_db_path)
df.to_sql('mshp_modeling_data', conn)
# Out:
# 12130
